# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [raw]
# deploy as seamlessly as possible
# get the predictions with history and live data

# %% [markdown]
# ![image.png](attachment:image.png)
